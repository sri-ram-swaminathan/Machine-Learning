# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots

# %% [markdown]
# #### Q8
# This exercise relates to the College data set, which can be found in the file College.csv on the book website. It contains a number of variables for 777 different universities and colleges in the US. The variables are
#
# - Private : Public/private indicator
# - Apps : Number of applications received
# - Accept : Number of applicants accepted
# - Enroll : Number of new students enrolled
# - Top10perc : New students from top 10 % of high school class
# - Top25perc : New students from top 25 % of high school class
# - F.Undergrad : Number of full-time undergraduates
# - P.Undergrad : Number of part-time undergraduates
# - Outstate : Out-of-state tuition
# - Room.Board : Room and board costs
# - Books : Estimated book costs
# - Personal : Estimated personal spending
# - PhD : Percent of faculty with Ph.D.s
# - Terminal : Percent of faculty with terminal degree
# - S.F.Ratio : Student/faculty ratio
# - perc.alumni : Percent of alumni who donate
# - Expend : Instructional expenditure per student
# - Grad.Rate : Graduation rate
#
# Before reading the data into Python, it can be viewed in Excel or a
# text editor.
#
# (a) Use the pd.read_csv() function to read the data into Python. Call the loaded data college. Make sure that you have the directory
# set to the correct location for the data.

# %%
college=pd.read_csv("College.csv")
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# (b) Look at the data used in the notebook by creating and running a new cell with just the code college in it. You should notice that the first column is just the name of each university in a column named something like Unnamed: 0. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later. Try the following commands and similarly look at the resulting data frames.

# %%
# treats the first column as the index
college2 = pd.read_csv('College.csv', index_col =0)

# renames the first column to college, and then makes it the index 
college3 = college.rename ({'Unnamed: 0': 'College '},
axis =1)
college3 = college3.set_index('College ')
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# This has used the first column in the file as an index for the data frame. This means that pandas has given each row a name corresponding to the appropriate university. Now you should see that the first data column is Private. Note that the names of the colleges appear on the left of the table. We also introduced a new python object above: a dictionary, which is specified by dictionary (key, value) pairs. Keep your modified version of the data with the following

# %%
college=college3

# %% [markdown]
# (c) Use the describe() method of to produce a numerical summary of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# (d) Use the pd.plotting.scatter_matrix() function to produce a scatterplot matrix of the first columns [Top10perc, Apps, Enroll]. Recall that you can reference a list C of columns of a data frame A using A[C].

# %%
columns=['Top10perc','Apps','Enroll']

pd.plotting.scatter_matrix(college[columns]);

# %% [markdown]
# (e) Use the boxplot() method of college to produce side-by-side boxplots of Outstate versus Private.

# %%
fig, ax = subplots(figsize=(8, 8))
college.boxplot('Outstate', by='Private', ax=ax);

# %% [markdown]
# (f) Create a new qualitative variable, called Elite, by binning the Top10perc variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%

# %%
elite_schools = ['Yes' if row['Top10perc']>50 else 'No' for index,row in college.iterrows()]
college['Elite'] = pd.Series(elite_schools,index=college.index)
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# Use the value_counts() method of college['Elite'] to see how many elite universities there are. Finally, use the boxplot() method again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
fig, ax = subplots(figsize=(8, 8))
college.boxplot('Outstate', by='Elite', ax=ax);

# %% [markdown]
# (g) Use the plot.hist() method of college to produce some histograms with differing numbers of bins for a few of the quantitative variables. The command plt.subplots(2, 2) may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %%
fig, ax = subplots(nrows=2,ncols=2,figsize=(15,5))
college.hist('Apps',ax=ax[0,0]);
college.hist('Accept',ax=ax[0,1]);
college.hist('PhD',ax=ax[1,0]);
college.hist('Grad.Rate',ax=ax[1,1]);

# %% [markdown]
# (h) Continue exploring the data, and provide a brief summary of what you discover.

# %%
fig,ax = subplots(nrows=2,ncols=2,figsize=(15,5))
college.hist('Room.Board',ax=ax[0,0],color='red');
college.hist('Books',ax=ax[0,1],color='red');
college.hist('Personal',ax=ax[1,0],color='red');
college.hist('Expend',ax=ax[1,1],color='green');

# %%
net_student_spend=college['Room.Board'].mean()+college['Books'].mean()+college['Personal'].mean()
print("The average amount that students spend per year is {0} $.".format(round(net_student_spend,2)))
# Out:
# The average amount that students spend per year is 6247.55 $.

# %% [markdown]
# The results of this analysis are as follows :
# > - There are more (median) private school applicants than public school applicants, coming from out of state.
# > - 10% of the schools in the list (78/777) are elite schools, with more than 50% of students who are in the top 10% of their high school class.
# > - More (median) students coming from out of state are accepted into elite schools, than rejected from them.
# > - The average (mean) accpetance rate is ~ 67%. 72 faculty members on average have a PhD degree.
# > - The average (mean) amount that a student spends on college per year is 6250 $.

# %% [markdown]
# > - Quantitative : (i) mpg (ii) cylinders (iii) displacement (iv) horsepower (v) weight (vi) acceleration (vii) year (viii) origin
# > - Qualitative :  (i) name

# %% [markdown]
# #### Q10
#
# This exercise involves the Boston housing data set.
#
# (a) To begin, load in the Boston data set, which is part of the ISLP
# library.

# %%
from ISLP import load_data
Boston = load_data('Boston')
Boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# (b) How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
print("The Boston data set has {0} rows and {1} columns".format(Boston.shape[0],Boston.shape[1]))
# Out:
# The Boston data set has 506 rows and 13 columns

# %% [markdown]
# Each row represents a suburb of Boston. The columns contain the following information :
#
# - crim: per capita crime rate by town.
#
# - zn: proportion of residential land zoned for lots over 25,000 sq.ft.
#
# - indus: proportion of non-retail business acres per town.
#
# - chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# - nox: nitrogen oxides concentration (parts per 10 million).
#
# - rm: average number of rooms per dwelling.
#
# - age: proportion of owner-occupied units built prior to 1940.
#
# - dis: weighted mean of distances to five Boston employment centres.
#
# - rad: index of accessibility to radial highways.
#
# - tax: full-value property-tax rate per $10,000.
#
# - ptratio: pupil-teacher ratio by town.
#
# - lstat: lower status of the population (percent).
#
# - medv: median value of owner-occupied homes in $1000s.

# %% [markdown]
# (c) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %%
fig, ax = subplots(nrows=1,ncols=2,figsize=(15,5))
Boston.plot.scatter(x='crim',y='lstat',ax=ax[0]);
Boston.plot.scatter(x='age',y='rm',ax=ax[1]);

# %%
fig, ax = subplots(nrows=1,ncols=2,figsize=(15,5))
Boston.plot.scatter(x='rad',y='ptratio',ax=ax[0]);
Boston.plot.scatter(x='medv',y='tax',ax=ax[1]);

# %% [markdown]
# I tried to find if a relation between predictors I felt were reasonable to associate. But there don't seem to be any direct relationships between the predictors that were tested. Probably a smarter thing to do is to form a correlation matrix.

# %% [markdown]
# (d) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %%
# compute the correlation between different predictors and order them 
corr = Boston.corr()
corr['crim'].sort_values()
# Out:
# medv      -0.388305
# dis       -0.379670
# rm        -0.219247
# zn        -0.200469
# chas      -0.055892
# ptratio    0.289946
# age        0.352734
# indus      0.406583
# nox        0.420972
# lstat      0.455621
# tax        0.582764
# rad        0.625505
# crim       1.000000
# Name: crim, dtype: float64

# %% [markdown]
# - Higher the access to radial highways, higher the crime rate.
# - Higher the median house price of owner homes, lower the crime rate.
#
# I would expect that percent of population in the lower status would be more positively correlated to crime rate.

# %% [markdown]
# (e) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
Boston.sort_values('crim',ascending=False)[0:5]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
#
#      ptratio  lstat  medv
# 380     20.2  17.21  10.4
# 418     20.2  20.62   8.8
# 405     20.2  22.98   5.0
# 410     20.2  10.11  15.0
# 414     20.2  36.98   7.0

# %%
Boston.sort_values('tax',ascending=False)[0:5]
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 492  0.11132  0.0  27.74     0  0.609  5.983  83.5  2.1099    4  711     20.1
# 491  0.10574  0.0  27.74     0  0.609  5.983  98.8  1.8681    4  711     20.1
# 490  0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4  711     20.1
# 489  0.18337  0.0  27.74     0  0.609  5.414  98.3  1.7554    4  711     20.1
# 488  0.15086  0.0  27.74     0  0.609  5.454  92.7  1.8209    4  711     20.1
#
#      lstat  medv
# 492  13.35  20.1
# 491  18.07  13.6
# 490  29.68   8.1
# 489  23.97   7.0
# 488  18.06  15.2

# %%
Boston.sort_values('ptratio',ascending=False)[0:5]
# Out:
#         crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 354  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4  334
# 355  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334
# 135  0.55778   0.0  21.89     0  0.624  6.335  98.2   2.1107    4  437
# 127  0.25915   0.0  21.89     0  0.624  5.693  96.0   1.7883    4  437
# 136  0.32264   0.0  21.89     0  0.624  5.942  93.5   1.9669    4  437
#
#      ptratio  lstat  medv
# 354     22.0   8.05  18.2
# 355     22.0   5.57  20.6
# 135     21.2  16.96  18.1
# 127     21.2  17.19  16.2
# 136     21.2  16.90  17.4

# %%
Boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# (f) How many of the suburbs in this data set bound the Charles river?

# %%
print("There are {0} suburbs bound to the Charles river".format(Boston['chas'].value_counts()[1]))
# Out:
# There are 35 suburbs bound to the Charles river

# %% [markdown]
# (g) What is the median pupil-teacher ratio among the towns in this data set?

# %%
print("The median pupil-teacher ratio is {0}".format(Boston['ptratio'].median()))
# Out:
# The median pupil-teacher ratio is 19.05

# %% [markdown]
# (h) Which suburb of Boston has lowest median value of owner-occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
Boston.loc[lambda df:df['medv']==Boston['medv'].min()]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %% [markdown]
# The suburbs with the lowest median value of owner occupied homes is #398 and #405. In comparison to the ranges the predictors are as follows :
#
# Number 398 :
# > - The crime rate lies in the fourth quartile and is 43% of the maximum value.
# > - No proportion of residential land is zoned for lots over 25,000 sq.ft, this is the minimum value.
# > - The proportion of non retail businesses lies in the third quartile and is 67% the maximum value.
# > - It is not bound to the Charles river.
# > - The nitrogen oxides concentration lies in the fourth quartile and is 79% the maximum value.
# > - The average number of rooms per dwelling lies in the first quartile and is 62% the maximum value.
# > - All homes built before 1940 are occupied by their owners, this is the maximum value.
# > - The weighted mean of distances to five Boston employment centres lies in the first quartile and is 12% the maximum value.
# > - The index of accessibility to radial highways lies in the third quartile, this is the maximum value.
# > - The full-value property-tax rate per $10,000 lies in the third quartile and is 93% the maximum value.
# > - The pupil-teacher ratio lies in the third quartile and is 92% the maximum value.
# > - The percent of the population in lower status is in the fourth quartile and is 81% the maximum value.
#
# Number 405 :
# > - The crime rate lies in the fourth quartile and is 76% of the maximum value.
# > - The average number of rooms per dwelling lies in the first quartile and is 64% the maximum value.
# > - The weighted mean of distances to five Boston employment centres lies in the first quartile and is 11.7% the maximum value.
# > - The percent of the population in lower status is in the fourth quartile and is 60% the maximum value.
#
# All other predictors have equal value.

# %% [markdown]
# (i) In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.

# %%
print("The number of suburbs that average more than 7 rooms are {0}".format(Boston.loc[lambda df:df['rm']>7.0].shape[0]))
print("While the number of suburbs that average more than 8 rooms are {0}".format(Boston.loc[lambda df:df['rm']>8.0].shape[0]))
# Out:
# The number of suburbs that average more than 7 rooms are 64
# While the number of suburbs that average more than 8 rooms are 13
